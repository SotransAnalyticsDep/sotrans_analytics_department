# %%
import sys

import numpy as np

sys.path.append(r'C:\Users\user\Desktop\github\sotrans_analytics_department')
from source.core.de.serving import Datamart

# %%
datamart: Datamart = Datamart(
    agg_cat_cols=('wh_name', 'brand_name_1c', 'sku_art_num'),
    agg_dgt_cols=('cnt',),
    agg_dt_cols=('year', 'week')
)
# Out:
# 2025-05-15 10:51:31.487 | DEBUG    | source.core.de.serving.datamart.datamart:calc_start_date:301 - Конечная дата анализируемого периода не задана, используется значение из Datamart: 2025-05-14
# 2025-05-15 10:51:31.487 | SUCCESS  | source.core.de.serving.datamart.datamart:calc_start_date:322 - Начальная дата анализируемого периода успешно рассчитана: 2024-06-01

# %%
# Количество дней с наличием товара
datamart.IHaving.add_stock(agg_dt_cols=('year', 'date'))
# Out:
# 2025-05-15 10:51:31.496 | DEBUG    | source.core.de.serving.datamart.datamart:__get_interface:255 - Создание интерфейса: IHaving
# 2025-05-15 10:51:31.497 | SUCCESS  | source.core.de.serving.datamart.datamart:__get_interface:257 - Интерфейс IHaving успешно создан
# 2025-05-15 10:51:31.497 | SUCCESS  | source.core.de.serving.datamart.modules.utils._validate_data:is_cols_available:87 - Кортеж доступных числовых столбцов: ('cnt',)
# 2025-05-15 10:51:31.498 | SUCCESS  | source.core.de.serving.datamart.modules.sql.sql_having:get_sql_query_stock:46 - SQL-запрос успешно сформирован
# 2025-05-15 11:17:13.907 | SUCCESS  | source.core.de.serving.datamart.modules.utils._sql_executor:execute_sql_query:52 - SQL-запрос успешно выполнен. DataFrame сформирован: (128659, 4)
# 2025-05-15 11:17:14.095 | SUCCESS  | source.core.de.serving.datamart.datamart:df:155 - Витрина данных обновлена: (128659, 4)

# %%
# Количество недель с наличием товара
datamart.IHaving.add_stock(agg_dt_cols=('year', 'week'))
# Out:
# 2025-05-15 11:17:14.106 | SUCCESS  | source.core.de.serving.datamart.modules.utils._validate_data:is_cols_available:87 - Кортеж доступных числовых столбцов: ('cnt',)
# 2025-05-15 11:17:14.106 | SUCCESS  | source.core.de.serving.datamart.modules.sql.sql_having:get_sql_query_stock:46 - SQL-запрос успешно сформирован
# 2025-05-15 11:43:08.471 | SUCCESS  | source.core.de.serving.datamart.modules.utils._sql_executor:execute_sql_query:52 - SQL-запрос успешно выполнен. DataFrame сформирован: (128659, 4)
# 2025-05-15 11:43:08.661 | SUCCESS  | source.core.de.serving.datamart.datamart:df:155 - Витрина данных обновлена: (128659, 5)

# %%
# Количество месяцев с наличием товара
datamart.IHaving.add_stock(agg_dt_cols=('year', 'month'))
# Out:
# 2025-05-15 11:43:08.670 | SUCCESS  | source.core.de.serving.datamart.modules.utils._validate_data:is_cols_available:87 - Кортеж доступных числовых столбцов: ('cnt',)
# 2025-05-15 11:43:08.671 | SUCCESS  | source.core.de.serving.datamart.modules.sql.sql_having:get_sql_query_stock:46 - SQL-запрос успешно сформирован
# 2025-05-15 12:07:52.672 | SUCCESS  | source.core.de.serving.datamart.modules.utils._sql_executor:execute_sql_query:52 - SQL-запрос успешно выполнен. DataFrame сформирован: (128659, 4)
# 2025-05-15 12:07:52.850 | SUCCESS  | source.core.de.serving.datamart.datamart:df:155 - Витрина данных обновлена: (128659, 6)

# %%
datamart.IHaving.add_sale(agg_dt_cols=('year', 'date'))
# Out:
# 2025-05-15 12:07:52.861 | SUCCESS  | source.core.de.serving.datamart.modules.sql.sql_having:get_sql_query_stock:46 - SQL-запрос успешно сформирован
# 2025-05-15 12:07:54.784 | SUCCESS  | source.core.de.serving.datamart.modules.utils._sql_executor:execute_sql_query:52 - SQL-запрос успешно выполнен. DataFrame сформирован: (93737, 4)
# 2025-05-15 12:07:55.066 | SUCCESS  | source.core.de.serving.datamart.datamart:df:155 - Витрина данных обновлена: (154415, 7)

# %%
datamart.IHaving.add_sale(agg_dt_cols=('year', 'week'))
# Out:
# 2025-05-15 12:07:55.074 | SUCCESS  | source.core.de.serving.datamart.modules.sql.sql_having:get_sql_query_stock:46 - SQL-запрос успешно сформирован
# 2025-05-15 12:07:56.790 | SUCCESS  | source.core.de.serving.datamart.modules.utils._sql_executor:execute_sql_query:52 - SQL-запрос успешно выполнен. DataFrame сформирован: (93737, 4)
# 2025-05-15 12:07:56.987 | SUCCESS  | source.core.de.serving.datamart.datamart:df:155 - Витрина данных обновлена: (154415, 8)

# %%
datamart.IHaving.add_sale(agg_dt_cols=('year', 'month'))
# Out:
# 2025-05-15 12:07:56.995 | SUCCESS  | source.core.de.serving.datamart.modules.sql.sql_having:get_sql_query_stock:46 - SQL-запрос успешно сформирован
# 2025-05-15 12:07:58.706 | SUCCESS  | source.core.de.serving.datamart.modules.utils._sql_executor:execute_sql_query:52 - SQL-запрос успешно выполнен. DataFrame сформирован: (93737, 4)
# 2025-05-15 12:07:58.887 | SUCCESS  | source.core.de.serving.datamart.datamart:df:155 - Витрина данных обновлена: (154415, 9)

# %%
datamart.df.sample(25)
# Out:
#                                      wh_name brand_name_1c    sku_art_num  \
# 75319                 магазин екатеринбург 1     harbinger       h1229165
# 64561               магазин великий новгород    shaft-gear        370309y
# 142568                    магазин тольятти 1           saf     3434402001
# 2652                        _не используется        covind         385213
# 134042      магазин санкт-петербург (парнас)         sampa          44070
# 39166   _склад санкт-петербург (красный бор)      dongfeng       c4327369
# 111208             магазин нижний новгород 2  victor reinz      713487400
# 81199                 магазин екатеринбург 2       simpeco     sp40040202
# 77495                 магазин екатеринбург 1         китай        ka30048
# 26014                       _не используется           газ        439091d
# 61088               магазин великий новгород       connect         md1810
# 21504                       _не используется        tangde    td0152002rw
# 65338               магазин великий новгород        tangde   zl0159010hpg
# 44716   _склад санкт-петербург (красный бор)         le.ma         600900
# 48364   _склад санкт-петербург (красный бор)         sampa        4238401
# 71688                        магазин воронеж         sampa        2401001
# 116619                  магазин петрозаводск      eurotech        1973010
# 42663   _склад санкт-петербург (красный бор)     harbinger       h3010279
# 94635                 магазин москва (ельня)    петропласт    ppl70500121
# 16019                       _не используется         pemco  dieselg55uhpd
# 33924                     _склад новосибирск           s&s         s23585
# 42742   _склад санкт-петербург (красный бор)     harbinger       h4010249
# 95244           магазин москва (ленинградка)          gtsa          78115
# 6489                        _не используется       gabriel          83021
# 30530                 _склад москва (речицы)         sampa          40117
#
#         hv_stock_12_date  hv_stock_12_week  hv_stock_12_month  \
# 75319              320.0              48.0               12.0
# 64561                8.0               2.0                1.0
# 142568             268.0              41.0               12.0
# 2652                90.0              14.0                4.0
# 134042               2.0               1.0                1.0
# 39166               43.0               7.0                3.0
# 111208               4.0               1.0                1.0
# 81199               11.0               2.0                1.0
# 77495              320.0              48.0               12.0
# 26014                NaN               NaN                NaN
# 61088              320.0              48.0               12.0
# 21504              181.0              28.0                8.0
# 65338                3.0               1.0                1.0
# 44716              320.0              48.0               12.0
# 48364              237.0              36.0               10.0
# 71688              286.0              43.0               11.0
# 116619             123.0              20.0                5.0
# 42663              320.0              48.0               12.0
# 94635               47.0               8.0                2.0
# 16019              260.0              39.0               10.0
# 33924              284.0              44.0               12.0
# 42742              320.0              48.0               12.0
# 95244               25.0               5.0                1.0
# 6489                89.0              14.0                4.0
# 30530               41.0               7.0                2.0
#
#         hv_sale_12_date  hv_sale_12_week  hv_sale_12_month
# 75319               NaN              NaN               NaN
# 64561               2.0              2.0               2.0
# 142568              6.0              6.0               5.0
# 2652                NaN              NaN               NaN
# 134042              1.0              1.0               1.0
# 39166               4.0              4.0               2.0
# 111208              2.0              2.0               2.0
# 81199               NaN              NaN               NaN
# 77495               NaN              NaN               NaN
# 26014               1.0              1.0               1.0
# 61088               NaN              NaN               NaN
# 21504               NaN              NaN               NaN
# 65338               1.0              1.0               1.0
# 44716               NaN              NaN               NaN
# 48364               NaN              NaN               NaN
# 71688               NaN              NaN               NaN
# 116619              NaN              NaN               NaN
# 42663               4.0              4.0               3.0
# 94635               1.0              1.0               1.0
# 16019               5.0              5.0               4.0
# 33924               NaN              NaN               NaN
# 42742               5.0              5.0               3.0
# 95244               NaN              NaN               NaN
# 6489                NaN              NaN               NaN
# 30530               NaN              NaN               NaN

# %%
with datamart.engine.begin() as connection:
    match datamart.agg_cat_cols:
        case ('brand_name_1c', 'sku_art_num'):
            allias: str = 'ba'
        case ('wh_name', 'brand_name_1c', 'sku_art_num'):
            allias: str = 'wba'
    
    datamart.df.to_sql(
        name=f'{allias}_having',
        schema='metrics',
        con=connection,
        index=False,
        if_exists='replace'
    )
